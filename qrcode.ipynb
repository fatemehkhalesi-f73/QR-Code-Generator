# %%
import qrcode as qr

# %%
img = qr.make("https://aiolearn.app")

# %%
img.show()

# %%
img.save('aiolearn_app.png')

# %%
img = qr.make("smsto:+9809901897739:salam khobi dadash!")

# %%
img.save('test1.png')

# %%
import wifi_qrcode

# %%
img = qr.make("wifi:s:fatemeh;t:WPA2-personal;p:12345678;;")

# %%
img.save('test2.png')
